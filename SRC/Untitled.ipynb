# %%
import pandas as pd
#importamos libreria pandas para lograr la visualización.
df = pd.read_csv('example.csv') sep=';'index_col=0
# sustituir "ejemplo.csv"por  el nombre del archivo correcto
# adaptar la separación ya se por "," o "." ó ";"
